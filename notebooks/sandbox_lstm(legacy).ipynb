# %% [markdown]
# # Load Training Data

# %%
import os
from random import shuffle

import numpy as np
import pandas as pd
import torch

from models.simple_lstm import SimpleLSTM
from pipeline.create_window_tensor import CreateWindowTensor
from data.feature_engineering import FeatureEngineering
from data.preprocessing import DataProcessing, PreProcessing

data_dir = '/Users/sebastian.angermund/Projects/data/hts'
TRAIN_DATA_DIR = os.path.join(data_dir, 'train')
TEST_DATA_DIR = os.path.join(data_dir, 'test')

# %%
class EarlyStopping:
    def __init__(self, patience=3, min_delta=1e-4, mode='min', verbose=True):
        """Args:
        patience (int): How many validations to wait before stopping if no improvement.
        min_delta (float): Minimum change to qualify as improvement.
        mode (str): 'min' for minimizing loss, 'max' for maximizing score (e.g., accuracy).
        verbose (bool): Whether to print when stopping.

        """
        self.patience = patience
        self.min_delta = min_delta
        self.mode = mode
        self.verbose = verbose
        self.best_score = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, current_score):
        if self.best_score is None:
            self.best_score = current_score
            return False

        improvement = (current_score < self.best_score - self.min_delta) if self.mode == 'min' else (current_score > self.best_score + self.min_delta)

        if improvement:
            self.best_score = current_score
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        return self.early_stop

# %%
import os
from random import shuffle

import numpy as np
import pandas as pd
import torch

from models.simple_lstm import SimpleLSTM
from pipeline.create_window_tensor import CreateWindowTensor
from data.feature_engineering import FeatureEngineering
from data.preprocessing import DataProcessing, PreProcessing

data_dir = '/Users/sebastian.angermund/Projects/data/hts'
TRAIN_DATA_DIR = os.path.join(data_dir, 'train')
TEST_DATA_DIR = os.path.join(data_dir, 'test')


class EarlyStopping:
    def __init__(self, patience=3, min_delta=1e-4, mode='min', verbose=True):
        """Args:
        patience (int): How many validations to wait before stopping if no improvement.
        min_delta (float): Minimum change to qualify as improvement.
        mode (str): 'min' for minimizing loss, 'max' for maximizing score (e.g., accuracy).
        verbose (bool): Whether to print when stopping.

        """
        self.patience = patience
        self.min_delta = min_delta
        self.mode = mode
        self.verbose = verbose
        self.best_score = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, current_score):
        if self.best_score is None:
            self.best_score = current_score
            return False

        improvement = (current_score < self.best_score - self.min_delta) if self.mode == 'min' else (current_score > self.best_score + self.min_delta)

        if improvement:
            self.best_score = current_score
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        return self.early_stop


def combine_races_to_tensor(pkl_files,
                            training_features,
                            target,
                            limit_contestants,
                            window_timesteps,
                            randomize):
    X_list = []
    y_list = []
    for pkl_file in pkl_files:
        df_race = pd.read_pickle(pkl_file)

        setup = PreProcessing(df=df_race, target=target)

        if not setup.valid:
            print(f'#### BROKEN DF: {pkl_file}')
            print(f'#### STATUS: n_horses: {setup.n_horses}, winner_index: {setup.winner_index}')
            print('#### SKIPPING')
            continue

        data_prep = DataProcessing(df=setup.df,
                                   winner_index=setup.winner_index,
                                   training_features=training_features)

        df_data_scaled, _ = data_prep.process_data()

        feature_prep = FeatureEngineering(df=df_data_scaled,
                                         training_features=training_features,
                                         target=target,
                                         limit_contestants=limit_contestants,
                                         target_int_mapping=setup.target_int_mapping,
                                         target_mapping=setup.target_mapping,
                                         n_horses=setup.n_horses,
                                         winner_index=setup.winner_index)
        try:
            df_feature = feature_prep.prepare_features()
        except ValueError as e:
            print(f'#### BROKEN DF: {pkl_file}')
            print(f'#### STATUS: {e}')
            print('#### SKIPPING')
            continue

        if len(df_feature) < window_timesteps:
            print(f'#### BROKEN DF: {pkl_file}')
            print('#### STATUS: Not enough data points')
            print('#### SKIPPING')
            continue

        windower = CreateWindowTensor(df=df_feature,
                                      target=target,
                                      n_horses=limit_contestants,
                                      window_timesteps=window_timesteps)

        X, y, _ = windower.create_sliding_windows2()

        X_list.append(X)
        y_list.append(y)

    X = np.concatenate(X_list)
    y = np.concatenate(y_list)

    if randomize:
        np.random.seed(42)
        indices = np.arange(X.shape[0])
        np.random.shuffle(indices)
        X = X[indices]
        y = y[indices]

    return X, y


def get_batch(train_files, training_features, target, contestants, window_timesteps, randomize_training_data, val_files=[]):
    X_train, y_train = combine_races_to_tensor(
        train_files,
        training_features,
        target,
        contestants,
        window_timesteps,
        randomize_training_data
    )
    if val_files:
        X_val, y_val = combine_races_to_tensor(
            val_files,
            training_features,
            target,
            contestants,
            window_timesteps,
            randomize_training_data
        )
    else:
        X_val, y_val = [], []
    return X_train, y_train, X_val, y_val


def fit_model(model, optimizer, loss_fn, X_train, y_train, X_val, y_val, epochs=5, batch_size=64, device='cuda'):
    model.train()
    # dataset = torch.utils.data.TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.long))
    dataset = torch.utils.data.TensorDataset(
        torch.tensor(X_train, dtype=torch.float32),
        torch.tensor(np.argmax(y_train, axis=1), dtype=torch.long)
    )
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

    # val_dataset = torch.utils.data.TensorDataset(torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val, dtype=torch.long))
    val_dataset = torch.utils.data.TensorDataset(
        torch.tensor(X_val, dtype=torch.float32),
        torch.tensor(np.argmax(y_val, axis=1), dtype=torch.long)
    )
    val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    history = {'loss': [], 'val_loss': []}

    for epoch in range(epochs):
        running_loss = 0.0
        for batch_X, batch_y in dataloader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = loss_fn(outputs, batch_y)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * batch_X.size(0)

        epoch_loss = running_loss / len(dataloader.dataset)
        history['loss'].append(epoch_loss)

        # Validation
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for val_X, val_y in val_dataloader:
                val_X, val_y = val_X.to(device), val_y.to(device)
                val_outputs = model(val_X)
                v_loss = loss_fn(val_outputs, val_y)
                val_loss += v_loss.item() * val_X.size(0)

        val_loss /= len(val_dataloader.dataset)
        history['val_loss'].append(val_loss)

        print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}")

        model.train()

    return history


def partition_race_files(path_to_files, partition_size):
    files = os.listdir(path_to_files)
    shuffle(files)
    n_partitions = len(files) // partition_size
    partitions = {f'partition_{i}': [] for i in range(n_partitions)}
    for i, file in enumerate(files):
        partition = i % n_partitions
        full_path = os.path.join(path_to_files, file)
        partitions[f'partition_{partition}'].append(full_path)
    return partitions


# Setup and run training loop:


batch_size = 32 # (races per batch)

batches = partition_race_files(TRAIN_DATA_DIR, batch_size)

limit_contestants = 6
target = 'finishOrder'
added_features = ['leader', 'distance_to_leader']
training_features = ['distance_to_finish', 'v_odds']
window_timesteps = 120

model = SimpleLSTM(
    training_features=training_features,
    added_features=added_features,
    num_contestants=limit_contestants,
)

device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
print(f'Using device: {device}')
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
loss_fn = torch.nn.CrossEntropyLoss()

for batch, files in batches.items():
    print(f'Loading {batch}')
    validation_part = int(len(files) * 0.2)
    train_files = files[validation_part:]
    val_files = files[:validation_part]
    X_train, y_train, X_val, y_val = get_batch(
        train_files=train_files,
        training_features=training_features,
        target=target,
        contestants=limit_contestants,
        window_timesteps=window_timesteps,
        randomize_training_data=False,
        val_files=val_files
    )
    history = fit_model(
        model=model,
        optimizer=optimizer,
        loss_fn=loss_fn,
        X_train=X_train,
        y_train=y_train,
        X_val=X_val,
        y_val=y_val,
        batch_size=64,
        device=device
    )
# Out:
# Using device: mps
# Loading partition_0
# X_train shape: (23689, 120, 24), y_train shape: (23689, 6)
# X_val shape: (5334, 120, 24), y_val shape: (5334, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7786, Val Loss: 1.9162
# Epoch [2/5], Train Loss: 1.7758, Val Loss: 1.9411
# Epoch [3/5], Train Loss: 1.7759, Val Loss: 1.9364
# Epoch [4/5], Train Loss: 1.7757, Val Loss: 1.9282
# Epoch [5/5], Train Loss: 1.7755, Val Loss: 1.9394
# Loading partition_1
# X_train shape: (23728, 120, 24), y_train shape: (23728, 6)
# X_val shape: (5295, 120, 24), y_val shape: (5295, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6886, Val Loss: 1.5987
# Epoch [2/5], Train Loss: 1.6659, Val Loss: 1.5960
# Epoch [3/5], Train Loss: 1.6651, Val Loss: 1.5933
# Epoch [4/5], Train Loss: 1.6642, Val Loss: 1.5990
# Epoch [5/5], Train Loss: 1.6643, Val Loss: 1.5814
# Loading partition_2
# X_train shape: (23451, 120, 24), y_train shape: (23451, 6)
# X_val shape: (5382, 120, 24), y_val shape: (5382, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6982, Val Loss: 2.6998
# Epoch [2/5], Train Loss: 1.6575, Val Loss: 2.6524
# Epoch [3/5], Train Loss: 1.6567, Val Loss: 2.6947
# Epoch [4/5], Train Loss: 1.6559, Val Loss: 2.6554
# Epoch [5/5], Train Loss: 1.6561, Val Loss: 2.7369
# Loading partition_3
# X_train shape: (23750, 120, 24), y_train shape: (23750, 6)
# X_val shape: (5262, 120, 24), y_val shape: (5262, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7602, Val Loss: 1.6584
# Epoch [2/5], Train Loss: 1.7327, Val Loss: 1.6678
# Epoch [3/5], Train Loss: 1.7321, Val Loss: 1.6609
# Epoch [4/5], Train Loss: 1.7321, Val Loss: 1.6503
# Epoch [5/5], Train Loss: 1.7324, Val Loss: 1.6531
# Loading partition_4
# X_train shape: (23614, 120, 24), y_train shape: (23614, 6)
# X_val shape: (5409, 120, 24), y_val shape: (5409, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6531, Val Loss: 2.1586
# Epoch [2/5], Train Loss: 1.6383, Val Loss: 2.1327
# Epoch [3/5], Train Loss: 1.6369, Val Loss: 2.1368
# Epoch [4/5], Train Loss: 1.6366, Val Loss: 2.1562
# Epoch [5/5], Train Loss: 1.6370, Val Loss: 2.1119
# Loading partition_5
# X_train shape: (23781, 120, 24), y_train shape: (23781, 6)
# X_val shape: (5369, 120, 24), y_val shape: (5369, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7311, Val Loss: 1.6130
# Epoch [2/5], Train Loss: 1.6875, Val Loss: 1.6042
# Epoch [3/5], Train Loss: 1.6865, Val Loss: 1.6073
# Epoch [4/5], Train Loss: 1.6854, Val Loss: 1.5870
# Epoch [5/5], Train Loss: 1.6858, Val Loss: 1.6132
# Loading partition_6
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-03-15_6_8.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22814, 120, 24), y_train shape: (22814, 6)
# X_val shape: (5201, 120, 24), y_val shape: (5201, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7008, Val Loss: 1.5059
# Epoch [2/5], Train Loss: 1.6687, Val Loss: 1.4835
# Epoch [3/5], Train Loss: 1.6677, Val Loss: 1.4828
# Epoch [4/5], Train Loss: 1.6673, Val Loss: 1.4803
# Epoch [5/5], Train Loss: 1.6674, Val Loss: 1.4833
# Loading partition_7
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-05-01_5_4.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22957, 120, 24), y_train shape: (22957, 6)
# X_val shape: (5318, 120, 24), y_val shape: (5318, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.5102, Val Loss: 2.5638
# Epoch [2/5], Train Loss: 1.4975, Val Loss: 2.5912
# Epoch [3/5], Train Loss: 1.4973, Val Loss: 2.5954
# Epoch [4/5], Train Loss: 1.4973, Val Loss: 2.5588
# Epoch [5/5], Train Loss: 1.4969, Val Loss: 2.5302
# Loading partition_8
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-07-30_15_5.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (23050, 120, 24), y_train shape: (23050, 6)
# X_val shape: (5278, 120, 24), y_val shape: (5278, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6886, Val Loss: 1.7887
# Epoch [2/5], Train Loss: 1.6823, Val Loss: 1.8047
# Epoch [3/5], Train Loss: 1.6824, Val Loss: 1.8011
# Epoch [4/5], Train Loss: 1.6822, Val Loss: 1.8144
# Epoch [5/5], Train Loss: 1.6822, Val Loss: 1.8115
# Loading partition_9
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-06-27_6_3.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22882, 120, 24), y_train shape: (22882, 6)
# X_val shape: (5257, 120, 24), y_val shape: (5257, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6818, Val Loss: 1.9200
# Epoch [2/5], Train Loss: 1.6496, Val Loss: 1.9279
# Epoch [3/5], Train Loss: 1.6483, Val Loss: 1.9421
# Epoch [4/5], Train Loss: 1.6471, Val Loss: 1.9430
# Epoch [5/5], Train Loss: 1.6476, Val Loss: 1.9275
# Loading partition_10
# X_train shape: (23801, 120, 24), y_train shape: (23801, 6)
# X_val shape: (5251, 120, 24), y_val shape: (5251, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7585, Val Loss: 1.6864
# Epoch [2/5], Train Loss: 1.7459, Val Loss: 1.7002
# Epoch [3/5], Train Loss: 1.7459, Val Loss: 1.6982
# Epoch [4/5], Train Loss: 1.7458, Val Loss: 1.6839
# Epoch [5/5], Train Loss: 1.7459, Val Loss: 1.6779
# Loading partition_11
# X_train shape: (23891, 120, 24), y_train shape: (23891, 6)
# X_val shape: (5224, 120, 24), y_val shape: (5224, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7176, Val Loss: 2.0064
# Epoch [2/5], Train Loss: 1.6990, Val Loss: 2.0405
# Epoch [3/5], Train Loss: 1.6984, Val Loss: 2.0076
# Epoch [4/5], Train Loss: 1.6982, Val Loss: 2.0404
# Epoch [5/5], Train Loss: 1.6983, Val Loss: 2.0298
# Loading partition_12
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-05-06_22_2.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22745, 120, 24), y_train shape: (22745, 6)
# X_val shape: (5213, 120, 24), y_val shape: (5213, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6127, Val Loss: 1.9194
# Epoch [2/5], Train Loss: 1.5807, Val Loss: 1.9047
# Epoch [3/5], Train Loss: 1.5802, Val Loss: 1.8965
# Epoch [4/5], Train Loss: 1.5798, Val Loss: 1.9130
# Epoch [5/5], Train Loss: 1.5799, Val Loss: 1.9101
# Loading partition_13
# X_train shape: (23671, 120, 24), y_train shape: (23671, 6)
# X_val shape: (5282, 120, 24), y_val shape: (5282, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7813, Val Loss: 1.7940
# Epoch [2/5], Train Loss: 1.7525, Val Loss: 1.7805
# Epoch [3/5], Train Loss: 1.7521, Val Loss: 1.7664
# Epoch [4/5], Train Loss: 1.7519, Val Loss: 1.7941
# Epoch [5/5], Train Loss: 1.7517, Val Loss: 1.7823
# Loading partition_14
# X_train shape: (23619, 120, 24), y_train shape: (23619, 6)
# X_val shape: (5289, 120, 24), y_val shape: (5289, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.5476, Val Loss: 3.3260
# Epoch [2/5], Train Loss: 1.4917, Val Loss: 3.6858
# Epoch [3/5], Train Loss: 1.4890, Val Loss: 3.7712
# Epoch [4/5], Train Loss: 1.4887, Val Loss: 3.9709
# Epoch [5/5], Train Loss: 1.4882, Val Loss: 3.9591
# Loading partition_15
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-02-21_5_4.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (23065, 120, 24), y_train shape: (23065, 6)
# X_val shape: (5359, 120, 24), y_val shape: (5359, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6323, Val Loss: 2.3417
# Epoch [2/5], Train Loss: 1.5627, Val Loss: 2.3589
# Epoch [3/5], Train Loss: 1.5627, Val Loss: 2.3787
# Epoch [4/5], Train Loss: 1.5617, Val Loss: 2.4168
# Epoch [5/5], Train Loss: 1.5618, Val Loss: 2.3690
# Loading partition_16
# X_train shape: (24070, 120, 24), y_train shape: (24070, 6)
# X_val shape: (5193, 120, 24), y_val shape: (5193, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6490, Val Loss: 1.7885
# Epoch [2/5], Train Loss: 1.6096, Val Loss: 1.7699
# Epoch [3/5], Train Loss: 1.6095, Val Loss: 1.7687
# Epoch [4/5], Train Loss: 1.6083, Val Loss: 1.7678
# Epoch [5/5], Train Loss: 1.6089, Val Loss: 1.7849
# Loading partition_17
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-10-29_14_3.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22868, 120, 24), y_train shape: (22868, 6)
# X_val shape: (5237, 120, 24), y_val shape: (5237, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7655, Val Loss: 1.9341
# Epoch [2/5], Train Loss: 1.7225, Val Loss: 1.9291
# Epoch [3/5], Train Loss: 1.7214, Val Loss: 1.9326
# Epoch [4/5], Train Loss: 1.7218, Val Loss: 1.9337
# Epoch [5/5], Train Loss: 1.7213, Val Loss: 1.9358
# Loading partition_18
# X_train shape: (23239, 120, 24), y_train shape: (23239, 6)
# X_val shape: (5198, 120, 24), y_val shape: (5198, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6270, Val Loss: 3.2625
# Epoch [2/5], Train Loss: 1.5725, Val Loss: 3.6406
# Epoch [3/5], Train Loss: 1.5712, Val Loss: 3.7742
# Epoch [4/5], Train Loss: 1.5703, Val Loss: 3.8165
# Epoch [5/5], Train Loss: 1.5695, Val Loss: 3.9514
# Loading partition_19
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-04-27_32_3.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (21989, 120, 24), y_train shape: (21989, 6)
# X_val shape: (5272, 120, 24), y_val shape: (5272, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7559, Val Loss: 1.6678
# Epoch [2/5], Train Loss: 1.6806, Val Loss: 1.6492
# Epoch [3/5], Train Loss: 1.6806, Val Loss: 1.6585
# Epoch [4/5], Train Loss: 1.6798, Val Loss: 1.6602
# Epoch [5/5], Train Loss: 1.6796, Val Loss: 1.6643
# Loading partition_20
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-03-05_32_6.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22217, 120, 24), y_train shape: (22217, 6)
# X_val shape: (5251, 120, 24), y_val shape: (5251, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.5956, Val Loss: 1.9718
# Epoch [2/5], Train Loss: 1.5766, Val Loss: 1.9669
# Epoch [3/5], Train Loss: 1.5766, Val Loss: 1.9696
# Epoch [4/5], Train Loss: 1.5766, Val Loss: 1.9627
# Epoch [5/5], Train Loss: 1.5763, Val Loss: 1.9842
# Loading partition_21
# X_train shape: (22694, 120, 24), y_train shape: (22694, 6)
# X_val shape: (5285, 120, 24), y_val shape: (5285, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7969, Val Loss: 1.9014
# Epoch [2/5], Train Loss: 1.7760, Val Loss: 1.8998
# Epoch [3/5], Train Loss: 1.7759, Val Loss: 1.9035
# Epoch [4/5], Train Loss: 1.7759, Val Loss: 1.9095
# Epoch [5/5], Train Loss: 1.7756, Val Loss: 1.8937
# Loading partition_22
# X_train shape: (22878, 120, 24), y_train shape: (22878, 6)
# X_val shape: (5088, 120, 24), y_val shape: (5088, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6849, Val Loss: 2.3757
# Epoch [2/5], Train Loss: 1.6726, Val Loss: 2.4007
# Epoch [3/5], Train Loss: 1.6724, Val Loss: 2.3903
# Epoch [4/5], Train Loss: 1.6723, Val Loss: 2.3884
# Epoch [5/5], Train Loss: 1.6721, Val Loss: 2.3992
# Loading partition_23
# X_train shape: (22794, 120, 24), y_train shape: (22794, 6)
# X_val shape: (5252, 120, 24), y_val shape: (5252, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6340, Val Loss: 2.4904
# Epoch [2/5], Train Loss: 1.5898, Val Loss: 2.6470
# Epoch [3/5], Train Loss: 1.5889, Val Loss: 2.7370
# Epoch [4/5], Train Loss: 1.5879, Val Loss: 2.8576
# Epoch [5/5], Train Loss: 1.5877, Val Loss: 2.8892
# Loading partition_24
# X_train shape: (22924, 120, 24), y_train shape: (22924, 6)
# X_val shape: (5282, 120, 24), y_val shape: (5282, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7650, Val Loss: 1.7109
# Epoch [2/5], Train Loss: 1.7036, Val Loss: 1.7384
# Epoch [3/5], Train Loss: 1.7022, Val Loss: 1.7277
# Epoch [4/5], Train Loss: 1.7022, Val Loss: 1.7239
# Epoch [5/5], Train Loss: 1.7019, Val Loss: 1.7406
# Loading partition_25
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-04-07_5_3.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22330, 120, 24), y_train shape: (22330, 6)
# X_val shape: (5280, 120, 24), y_val shape: (5280, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.5882, Val Loss: 1.8548
# Epoch [2/5], Train Loss: 1.5354, Val Loss: 1.8659
# Epoch [3/5], Train Loss: 1.5333, Val Loss: 1.8729
# Epoch [4/5], Train Loss: 1.5337, Val Loss: 1.8742
# Epoch [5/5], Train Loss: 1.5327, Val Loss: 1.9092
# Loading partition_26
# X_train shape: (22744, 120, 24), y_train shape: (22744, 6)
# X_val shape: (5324, 120, 24), y_val shape: (5324, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7581, Val Loss: 1.7522
# Epoch [2/5], Train Loss: 1.7441, Val Loss: 1.7498
# Epoch [3/5], Train Loss: 1.7440, Val Loss: 1.7492
# Epoch [4/5], Train Loss: 1.7434, Val Loss: 1.7460
# Epoch [5/5], Train Loss: 1.7440, Val Loss: 1.7496
# Loading partition_27
# X_train shape: (22864, 120, 24), y_train shape: (22864, 6)
# X_val shape: (5274, 120, 24), y_val shape: (5274, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6842, Val Loss: 2.0872
# Epoch [2/5], Train Loss: 1.6699, Val Loss: 2.1034
# Epoch [3/5], Train Loss: 1.6699, Val Loss: 2.0755
# Epoch [4/5], Train Loss: 1.6695, Val Loss: 2.0792
# Epoch [5/5], Train Loss: 1.6700, Val Loss: 2.0833
# Loading partition_28
# X_train shape: (22848, 120, 24), y_train shape: (22848, 6)
# X_val shape: (5316, 120, 24), y_val shape: (5316, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6483, Val Loss: 2.1203
# Epoch [2/5], Train Loss: 1.6132, Val Loss: 2.1348
# Epoch [3/5], Train Loss: 1.6131, Val Loss: 2.1421
# Epoch [4/5], Train Loss: 1.6134, Val Loss: 2.1016
# Epoch [5/5], Train Loss: 1.6128, Val Loss: 2.1227
# Loading partition_29
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-04-10_5_2.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22799, 120, 24), y_train shape: (22799, 6)
# X_val shape: (4371, 120, 24), y_val shape: (4371, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7547, Val Loss: 1.8956
# Epoch [2/5], Train Loss: 1.7263, Val Loss: 1.8944
# Epoch [3/5], Train Loss: 1.7262, Val Loss: 1.9032
# Epoch [4/5], Train Loss: 1.7259, Val Loss: 1.9024
# Epoch [5/5], Train Loss: 1.7257, Val Loss: 1.9043
# Loading partition_30
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-05-11_27_2.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (21732, 120, 24), y_train shape: (21732, 6)
# X_val shape: (5137, 120, 24), y_val shape: (5137, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7565, Val Loss: 1.8347
# Epoch [2/5], Train Loss: 1.7526, Val Loss: 1.8368
# Epoch [3/5], Train Loss: 1.7526, Val Loss: 1.8334
# Epoch [4/5], Train Loss: 1.7525, Val Loss: 1.8350
# Epoch [5/5], Train Loss: 1.7525, Val Loss: 1.8409
# Loading partition_31
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-09-03_9_2.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-03-13_9_1.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22092, 120, 24), y_train shape: (22092, 6)
# X_val shape: (4351, 120, 24), y_val shape: (4351, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7211, Val Loss: 1.8113
# Epoch [2/5], Train Loss: 1.7059, Val Loss: 1.8171
# Epoch [3/5], Train Loss: 1.7058, Val Loss: 1.8301
# Epoch [4/5], Train Loss: 1.7054, Val Loss: 1.8188
# Epoch [5/5], Train Loss: 1.7049, Val Loss: 1.8171
# Loading partition_32
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-04-30_7_3.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-06-07_16_3.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (20985, 120, 24), y_train shape: (20985, 6)
# X_val shape: (5284, 120, 24), y_val shape: (5284, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7433, Val Loss: 1.7679
# Epoch [2/5], Train Loss: 1.7379, Val Loss: 1.7733
# Epoch [3/5], Train Loss: 1.7376, Val Loss: 1.7718
# Epoch [4/5], Train Loss: 1.7378, Val Loss: 1.7715
# Epoch [5/5], Train Loss: 1.7377, Val Loss: 1.7756
# Loading partition_33
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-03-13_5_2.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22141, 120, 24), y_train shape: (22141, 6)
# X_val shape: (5318, 120, 24), y_val shape: (5318, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7642, Val Loss: 2.1198
# Epoch [2/5], Train Loss: 1.7556, Val Loss: 2.0928
# Epoch [3/5], Train Loss: 1.7555, Val Loss: 2.0819
# Epoch [4/5], Train Loss: 1.7553, Val Loss: 2.0933
# Epoch [5/5], Train Loss: 1.7551, Val Loss: 2.1216
# Loading partition_34
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-04-26_27_4.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22109, 120, 24), y_train shape: (22109, 6)
# X_val shape: (5312, 120, 24), y_val shape: (5312, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6506, Val Loss: 1.9238
# Epoch [2/5], Train Loss: 1.6159, Val Loss: 1.9008
# Epoch [3/5], Train Loss: 1.6155, Val Loss: 1.9269
# Epoch [4/5], Train Loss: 1.6150, Val Loss: 1.9266
# Epoch [5/5], Train Loss: 1.6149, Val Loss: 1.9296
# Loading partition_35
# X_train shape: (22984, 120, 24), y_train shape: (22984, 6)
# X_val shape: (5217, 120, 24), y_val shape: (5217, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6358, Val Loss: 2.0965
# Epoch [2/5], Train Loss: 1.6239, Val Loss: 2.0777
# Epoch [3/5], Train Loss: 1.6237, Val Loss: 2.0854
# Epoch [4/5], Train Loss: 1.6234, Val Loss: 2.0855
# Epoch [5/5], Train Loss: 1.6234, Val Loss: 2.0947
# Loading partition_36
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-03-21_9_3.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (21892, 120, 24), y_train shape: (21892, 6)
# X_val shape: (5338, 120, 24), y_val shape: (5338, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7278, Val Loss: 2.0002
# Epoch [2/5], Train Loss: 1.6980, Val Loss: 2.0090
# Epoch [3/5], Train Loss: 1.6974, Val Loss: 1.9751
# Epoch [4/5], Train Loss: 1.6961, Val Loss: 1.9972
# Epoch [5/5], Train Loss: 1.6962, Val Loss: 2.0031
# Loading partition_37
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-02-22_9_3.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22869, 120, 24), y_train shape: (22869, 6)
# X_val shape: (4354, 120, 24), y_val shape: (4354, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7270, Val Loss: 2.1606
# Epoch [2/5], Train Loss: 1.6962, Val Loss: 2.1801
# Epoch [3/5], Train Loss: 1.6950, Val Loss: 2.1498
# Epoch [4/5], Train Loss: 1.6950, Val Loss: 2.1637
# Epoch [5/5], Train Loss: 1.6948, Val Loss: 2.1448
# Loading partition_38
# X_train shape: (22829, 120, 24), y_train shape: (22829, 6)
# X_val shape: (5261, 120, 24), y_val shape: (5261, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7754, Val Loss: 1.8276
# Epoch [2/5], Train Loss: 1.7699, Val Loss: 1.8206
# Epoch [3/5], Train Loss: 1.7694, Val Loss: 1.8178
# Epoch [4/5], Train Loss: 1.7692, Val Loss: 1.8260
# Epoch [5/5], Train Loss: 1.7692, Val Loss: 1.8223
# Loading partition_39
# X_train shape: (22823, 120, 24), y_train shape: (22823, 6)
# X_val shape: (5307, 120, 24), y_val shape: (5307, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7112, Val Loss: 1.8888
# Epoch [2/5], Train Loss: 1.7034, Val Loss: 1.8763
# Epoch [3/5], Train Loss: 1.7030, Val Loss: 1.8869
# Epoch [4/5], Train Loss: 1.7030, Val Loss: 1.8869
# Epoch [5/5], Train Loss: 1.7032, Val Loss: 1.8813
# Loading partition_40
# #### BROKEN DF: /Users/sebastian.angermund/Projects/data/hts/train/2024-04-19_33_4.pkl
# #### STATUS: Not enough horses to pick from
# #### SKIPPING
# X_train shape: (22054, 120, 24), y_train shape: (22054, 6)
# X_val shape: (5318, 120, 24), y_val shape: (5318, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6703, Val Loss: 2.2668
# Epoch [2/5], Train Loss: 1.6358, Val Loss: 2.2842
# Epoch [3/5], Train Loss: 1.6356, Val Loss: 2.2597
# Epoch [4/5], Train Loss: 1.6350, Val Loss: 2.2606
# Epoch [5/5], Train Loss: 1.6349, Val Loss: 2.2604
# Loading partition_41
# X_train shape: (23086, 120, 24), y_train shape: (23086, 6)
# X_val shape: (5353, 120, 24), y_val shape: (5353, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7666, Val Loss: 1.6755
# Epoch [2/5], Train Loss: 1.7404, Val Loss: 1.6856
# Epoch [3/5], Train Loss: 1.7403, Val Loss: 1.6748
# Epoch [4/5], Train Loss: 1.7398, Val Loss: 1.6861
# Epoch [5/5], Train Loss: 1.7396, Val Loss: 1.6956
# Loading partition_42
# X_train shape: (22894, 120, 24), y_train shape: (22894, 6)
# X_val shape: (5230, 120, 24), y_val shape: (5230, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6871, Val Loss: 2.0071
# Epoch [2/5], Train Loss: 1.6549, Val Loss: 2.0068
# Epoch [3/5], Train Loss: 1.6542, Val Loss: 2.0057
# Epoch [4/5], Train Loss: 1.6541, Val Loss: 2.0177
# Epoch [5/5], Train Loss: 1.6536, Val Loss: 2.0217
# Loading partition_43
# X_train shape: (23278, 120, 24), y_train shape: (23278, 6)
# X_val shape: (5286, 120, 24), y_val shape: (5286, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.7323, Val Loss: 1.9242
# Epoch [2/5], Train Loss: 1.7134, Val Loss: 1.9412
# Epoch [3/5], Train Loss: 1.7135, Val Loss: 1.9539
# Epoch [4/5], Train Loss: 1.7131, Val Loss: 1.9466
# Epoch [5/5], Train Loss: 1.7130, Val Loss: 1.9462
# Loading partition_44
# X_train shape: (22826, 120, 24), y_train shape: (22826, 6)
# X_val shape: (5252, 120, 24), y_val shape: (5252, 6)
# Fitting model...
# Epoch [1/5], Train Loss: 1.6711, Val Loss: 2.0935
# Epoch [2/5], Train Loss: 1.6562, Val Loss: 2.1004
# Epoch [3/5], Train Loss: 1.6560, Val Loss: 2.1011
# Epoch [4/5], Train Loss: 1.6561, Val Loss: 2.0963
# Epoch [5/5], Train Loss: 1.6559, Val Loss: 2.1072

# %% [markdown]
# # Test

# %%
import json
import os

import torch
from sklearn.calibration import calibration_curve
from sklearn.metrics import auc, average_precision_score, brier_score_loss, log_loss, precision_recall_curve, roc_curve


def get_testing_data(window_timesteps, training_features, target, limit_contestants, n_test_files=25):
    pkl_files = [os.path.join(TEST_DATA_DIR, file) for file in os.listdir(TEST_DATA_DIR)]
    pkl_files = pkl_files[:n_test_files]  # Limit for sandboxing
    X_test, y_test = combine_races_to_tensor(
        pkl_files=pkl_files,
        training_features=training_features,
        target=target,
        limit_contestants=limit_contestants,
        window_timesteps=window_timesteps,
        randomize=False
    )
    return X_test, y_test

def run_model(model, X_test, y_test, device, batch_size=32):
    model.eval()

    X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
    y_test_tensor = torch.tensor(np.argmax(y_test, axis=1), dtype=torch.long).to(device)  # Convert test labels to class indices

    test_dataset = torch.utils.data.TensorDataset(X_test_tensor, y_test_tensor)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    total_loss = 0.0
    correct = 0
    total = 0
    y_preds = []

    loss_fn = torch.nn.CrossEntropyLoss()

    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            outputs = model(batch_X)
            loss = loss_fn(outputs, batch_y)
            total_loss += loss.item() * batch_X.size(0)

            preds = torch.softmax(outputs, dim=1)  # Get predicted probabilities
            y_preds.append(preds.cpu().numpy())

            predicted_classes = torch.argmax(preds, dim=1)
            correct += (predicted_classes == batch_y).sum().item()
            total += batch_X.size(0)

    avg_loss = total_loss / total
    accuracy = correct / total
    y_pred_all = np.concatenate(y_preds, axis=0)

    return accuracy, avg_loss, y_pred_all

def evaluate_predictions(y_true, y_pred, mode='micro'):
    results = {}

    if mode == 'micro':
        # Flatten for metrics that treat each horse separately
        y_true_flat = np.ndarray.flatten(np.array(y_true))
        y_pred_flat = np.ndarray.flatten(y_pred)

        results['average_precision'] = average_precision_score(y_true_flat, y_pred_flat, average='micro')
        results['brier_score'] = brier_score_loss(y_true_flat, y_pred_flat)
        results['log_loss'] = log_loss(y_true_flat, y_pred_flat)

        # Curves
        prob_true, prob_pred = calibration_curve(y_true_flat, y_pred_flat, n_bins=10)
        fpr, tpr, _ = roc_curve(y_true_flat, y_pred_flat)
        precision, recall, _ = precision_recall_curve(y_true_flat, y_pred_flat)

        results['calibration_curve'] = {'prob_true': prob_true.tolist(), 'prob_pred': prob_pred.tolist()}
        results['roc_curve'] = {'fpr': fpr.tolist(), 'tpr': tpr.tolist(), 'auc': auc(fpr, tpr)}
        results['pr_curve'] = {'precision': precision.tolist(), 'recall': recall.tolist()}

    elif mode == 'macro':
        # Winner prediction by argmax
        y_pred_indices = np.argmax(y_pred, axis=1)
        y_true_indices = np.argmax(y_true, axis=1)  # Assuming y_true is still multi-hot

        winner_accuracy = np.mean(y_pred_indices == y_true_indices)
        results['winner_accuracy'] = winner_accuracy

    return results

# Main testing block
X_test, y_test = get_testing_data(
    window_timesteps=window_timesteps,
    training_features=training_features,
    target=target,
    limit_contestants=limit_contestants
)

accuracy, loss, y_pred = run_model(model, X_test, y_test, device)

# Compute both micro (probabilities) and macro (winner picking) evaluations
micro_metrics = evaluate_predictions(y_test, y_pred, mode='micro')
macro_metrics = evaluate_predictions(y_test, y_pred, mode='macro')

print("\n--- Scalar Metrics ---")
print(json.dumps({
    'model_accuracy': accuracy,
    'model_loss': loss,
    # **micro_metrics  # unpack micro metrics here
}, indent=4))

print("\n--- Winner Prediction Metrics ---")
print(json.dumps(macro_metrics, indent=4))
# Out:
# --- Scalar Metrics ---
# {
#     "model_accuracy": 0.23603021477975974,
#     "model_loss": 1.7950656537277117
# }
#
# --- Winner Prediction Metrics ---
# {
#     "winner_accuracy": 0.23603021477975974
# }
